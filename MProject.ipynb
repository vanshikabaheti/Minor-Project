# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikabaheti/Minor-Project/blob/main/MProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
# Mounted at /content/drive

# %%
import os

# %%
import cv2
import numpy as np
from PIL import Image
import pathlib
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (19).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/27 (10).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (28).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (25).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (21).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (20).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (23).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (27).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (26).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/MildDemented/26 (24).jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/31 (2).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/30.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/28.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/29 (2).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/32 (2).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/30 (2).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/28 (2).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/31.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/ModerateDemented/29.jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (67).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (62).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (69).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (73).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (74).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (70).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (85).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (68).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (64).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/NonDemented/26 (63).jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (46).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (61).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (54).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (62).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (50).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (44).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (59).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (45).jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/test/VeryMildDemented/26 (60).jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem1.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem10.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem0.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem100.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem124.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem111.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem113.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem115.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/MildDemented/mildDem12.jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem10.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem1.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem0.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem26.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem20.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem3.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem2.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem12.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/ModerateDemented/moderateDem13.jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1611.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1623.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem161.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1619.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1614.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1612.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1621.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1624.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/NonDemented/nonDem1616.jpg done...
# ...

# %%
maxsize = (500, 600)
for input_img_path in pathlib.Path("/content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented").iterdir():
    output_img_path = str(input_img_path).replace("input", "output")
    with Image.open(input_img_path) as im:
        im = cv2.imread(str(input_img_path))
        im = cv2.resize(im, (500, 600))
        image_bw = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        clahe = cv2.createCLAHE(clipLimit=5)
        im = clahe.apply(image_bw) + 0
        cv2.imwrite(str(output_img_path), im)
        print(f"processing file {input_img_path} done...")
# Out:
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1533.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1531.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1532.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1530.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1527.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1537.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1525.jpg done...
# processing file /content/drive/MyDrive/Alzheimer_s Dataset/train/VeryMildDemented/verymildDem1534.jpg done...
# ...

# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from pathlib import Path

import cv2
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Input
from tensorflow.keras.layers import BatchNormalization

# %%
base_dir = ("/content/drive/MyDrive/Alzheimer_s Dataset")

# %%
train = ImageDataGenerator(rescale=1./255)
test =  ImageDataGenerator(rescale=1./255)
val =  ImageDataGenerator(rescale=1./255)

# %%
train= base_dir+ "/train"

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='training',
    seed=1000 )
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.

# %%
val=base_dir+ '/train/'

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    val,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='validation',
    seed=1000
    )
# Out:
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.

# %%
test=base_dir +'/test/'

test_data=tf.keras.preprocessing.image_dataset_from_directory(
    test,
    image_size=(224,224),
    batch_size=32,
    seed=1000
    )
# Out:
# Found 1289 files belonging to 4 classes.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']

# %%
train_data.class_names = class_names
val_data.class_names = class_names

# %%
print(val_data)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train_data.class_names[labels[i]])
        plt.axis("off")
plt.savefig("sample.png")

# %%
model=Sequential()

model.add(Conv2D(16,(3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(256,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.7))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32,activation='relu'))
model.add(Dense(4,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 12, 12, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
# ...

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_data, validation_data=val_data, epochs=50)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 248s 2s/step - loss: 3.3734 - accuracy: 0.3898 - val_loss: 1.2640 - val_accuracy: 0.4697
# Epoch 2/50
# 129/129 [==============================] - 240s 2s/step - loss: 1.2323 - accuracy: 0.4120 - val_loss: 1.2622 - val_accuracy: 0.4277
# Epoch 3/50
# 129/129 [==============================] - 239s 2s/step - loss: 1.1987 - accuracy: 0.4286 - val_loss: 1.2138 - val_accuracy: 0.4990
# Epoch 4/50
# 129/129 [==============================] - 233s 2s/step - loss: 1.1618 - accuracy: 0.4484 - val_loss: 1.1486 - val_accuracy: 0.3760
# Epoch 5/50
# 129/129 [==============================] - 235s 2s/step - loss: 1.1484 - accuracy: 0.4469 - val_loss: 1.1868 - val_accuracy: 0.5127
# Epoch 6/50
# 129/129 [==============================] - 234s 2s/step - loss: 1.1308 - accuracy: 0.4506 - val_loss: 1.1532 - val_accuracy: 0.5107
# Epoch 7/50
# ...

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("train_vs_val_loss.png")
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
plt.plot(accuracy_train, 'g', label='Training accuracy')
plt.plot(accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("train_vs_val_acc.png")
plt.show()

# %%
class_names={0:"Mild Dementia", 1:"Moderate Dementia", 2:"Non Dementia", 3:"Very Mild Dementia"}

# %%
plt.figure(figsize=(18,8))
for images, labels in val_data.take(1):
    for i in range(10):
        plt.subplot(2,5,i+1)
        plt.imshow(images[i]/255)
        frame1 = plt.gca()
        frame1.axes.xaxis.set_ticklabels([])
        frame1.axes.yaxis.set_ticklabels([])
        x = image.img_to_array(images[i])
        x = np.expand_dims(x, axis=0)
        p=np.argmax(model.predict(x))    
        plt.title("Predicted: {}".format(class_names[p]))
        plt.xlabel("True Class: {}".format(val_data.class_names[labels[i]]))
